# %%
pip install streamlit
# Out:
# Collecting streamlitNote: you may need to restart the kernel to use updated packages.
#
#   Downloading streamlit-1.38.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (4.25.4)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-17.0.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\jacob\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\jacob\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jacob\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: colorama in c:\users\jacob\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jacob\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jacob\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jacob\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jacob\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jacob\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jacob\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jacob\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jacob\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jacob\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jacob\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jacob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jacob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jacob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jacob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jacob\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\jacob\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.7 MB 10.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.4/8.7 MB 25.3 MB/s eta 0:00:01
#    -------------------- ------------------- 4.5/8.7 MB 31.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.6/8.7 MB 35.1 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 36.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 34.9 MB/s eta 0:00:00
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ---------------------------------------- 0.0/658.1 kB ? eta -:--:--
#    --------------------------------------- 658.1/658.1 kB 43.2 MB/s eta 0:00:00
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ---------------------------------------- 0.0/207.3 kB ? eta -:--:--
#    ---------------------------------------- 207.3/207.3 kB ? eta 0:00:00
# Downloading pyarrow-17.0.0-cp39-cp39-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    -- ------------------------------------- 1.9/25.1 MB 39.7 MB/s eta 0:00:01
#    ------ --------------------------------- 4.0/25.1 MB 42.4 MB/s eta 0:00:01
#    --------- ------------------------------ 6.2/25.1 MB 43.6 MB/s eta 0:00:01
#    ------------- -------------------------- 8.2/25.1 MB 43.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 10.3/25.1 MB 46.7 MB/s eta 0:00:01
#    ------------------- -------------------- 12.3/25.1 MB 46.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 14.4/25.1 MB 46.7 MB/s eta 0:00:01
#    -------------------------- ------------- 16.5/25.1 MB 46.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.6/25.1 MB 46.7 MB/s eta 0:00:01
#    -------------------------------- ------- 20.7/25.1 MB 46.9 MB/s eta 0:00:01
#    ------------------------------------ --- 22.8/25.1 MB 46.9 MB/s eta 0:00:01
#    ---------------------------------------  25.0/25.1 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 40.9 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ----------- ---------------------------- 2.0/6.9 MB 64.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.1/6.9 MB 52.9 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 50.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 44.2 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# Downloading narwhals-1.7.0-py3-none-any.whl (165 kB)
#    ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#    --------------------------------------- 165.9/165.9 kB 10.4 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, pyarrow, narwhals, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.4.1 blinker-1.8.2 cachetools-5.5.0 gitdb-4.0.11 gitpython-3.1.43 narwhals-1.7.0 pyarrow-17.0.0 pydeck-0.9.1 smmap-5.0.1 streamlit-1.38.0

# %%
import streamlit as st
import pickle
import numpy as np
with open('../model/plank_dp.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
st.title("Plank correction prediction")
# Out:
# 2024-09-11 13:37:39.845 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 13:37:40.630
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Jacob\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-09-11 13:37:40.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Input fields for all features
nose_x = st.number_input("Nose X", value=0.0)
nose_y = st.number_input("Nose Y", value=0.0)
nose_z = st.number_input("Nose Z", value=0.0)
nose_v = st.number_input("Nose V", value=1.0)

left_shoulder_x = st.number_input("Left Shoulder X", value=0.0)
left_shoulder_y = st.number_input("Left Shoulder Y", value=0.0)
left_shoulder_z = st.number_input("Left Shoulder Z", value=0.0)
left_shoulder_v = st.number_input("Left Shoulder V", value=1.0)

right_shoulder_x = st.number_input("Right Shoulder X", value=0.0)
right_shoulder_y = st.number_input("Right Shoulder Y", value=0.0)
right_shoulder_z = st.number_input("Right Shoulder Z", value=0.0)
right_shoulder_v = st.number_input("Right Shoulder V", value=1.0)

left_elbow_x = st.number_input("Left Elbow X", value=0.0)
left_elbow_y = st.number_input("Left Elbow Y", value=0.0)
left_elbow_z = st.number_input("Left Elbow Z", value=0.0)
left_elbow_v = st.number_input("Left Elbow V", value=1.0)

right_elbow_x = st.number_input("Right Elbow X", value=0.0)
right_elbow_y = st.number_input("Right Elbow Y", value=0.0)
right_elbow_z = st.number_input("Right Elbow Z", value=0.0)
right_elbow_v = st.number_input("Right Elbow V", value=1.0)

left_wrist_x = st.number_input("Left Wrist X", value=0.0)
left_wrist_y = st.number_input("Left Wrist Y", value=0.0)
left_wrist_z = st.number_input("Left Wrist Z", value=0.0)
left_wrist_v = st.number_input("Left Wrist V", value=1.0)

right_wrist_x = st.number_input("Right Wrist X", value=0.0)
right_wrist_y = st.number_input("Right Wrist Y", value=0.0)
right_wrist_z = st.number_input("Right Wrist Z", value=0.0)
right_wrist_v = st.number_input("Right Wrist V", value=1.0)

left_hip_x = st.number_input("Left Hip X", value=0.0)
left_hip_y = st.number_input("Left Hip Y", value=0.0)
left_hip_z = st.number_input("Left Hip Z", value=0.0)
left_hip_v = st.number_input("Left Hip V", value=1.0)

right_hip_x = st.number_input("Right Hip X", value=0.0)
right_hip_y = st.number_input("Right Hip Y", value=0.0)
right_hip_z = st.number_input("Right Hip Z", value=0.0)
right_hip_v = st.number_input("Right Hip V", value=1.0)

left_knee_x = st.number_input("Left Knee X", value=0.0)
left_knee_y = st.number_input("Left Knee Y", value=0.0)
left_knee_z = st.number_input("Left Knee Z", value=0.0)
left_knee_v = st.number_input("Left Knee V", value=1.0)

right_knee_x = st.number_input("Right Knee X", value=0.0)
right_knee_y = st.number_input("Right Knee Y", value=0.0)
right_knee_z = st.number_input("Right Knee Z", value=0.0)
right_knee_v = st.number_input("Right Knee V", value=1.0)

left_ankle_x = st.number_input("Left Ankle X", value=0.0)
left_ankle_y = st.number_input("Left Ankle Y", value=0.0)
left_ankle_z = st.number_input("Left Ankle Z", value=0.0)
left_ankle_v = st.number_input("Left Ankle V", value=1.0)

right_ankle_x = st.number_input("Right Ankle X", value=0.0)
right_ankle_y = st.number_input("Right Ankle Y", value=0.0)
right_ankle_z = st.number_input("Right Ankle Z", value=0.0)
right_ankle_v = st.number_input("Right Ankle V", value=1.0)

left_heel_x = st.number_input("Left Heel X", value=0.0)
left_heel_y = st.number_input("Left Heel Y", value=0.0)
left_heel_z = st.number_input("Left Heel Z", value=0.0)
left_heel_v = st.number_input("Left Heel V", value=1.0)

right_heel_x = st.number_input("Right Heel X", value=0.0)
right_heel_y = st.number_input("Right Heel Y", value=0.0)
right_heel_z = st.number_input("Right Heel Z", value=0.0)
right_heel_v = st.number_input("Right Heel V", value=1.0)

left_foot_index_x = st.number_input("Left Foot Index X", value=0.0)
left_foot_index_y = st.number_input("Left Foot Index Y", value=0.0)
left_foot_index_z = st.number_input("Left Foot Index Z", value=0.0)
left_foot_index_v = st.number_input("Left Foot Index V", value=1.0)

right_foot_index_x = st.number_input("Right Foot Index X", value=0.0)
right_foot_index_y = st.number_input("Right Foot Index Y", value=0.0)
right_foot_index_z = st.number_input("Right Foot Index Z", value=0.0)
right_foot_index_v = st.number_input("Right Foot Index V", value=1.0)
# Out:
# 2024-09-11 14:15:30.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.856 Session state does not function when running a script without `streamlit run`
# 2024-09-11 14:15:30.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:15:30.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Collect input into a single list
input_data = np.array([
    nose_x, nose_y, nose_z, nose_v,
    left_shoulder_x, left_shoulder_y, left_shoulder_z, left_shoulder_v,
    right_shoulder_x, right_shoulder_y, right_shoulder_z, right_shoulder_v,
    left_elbow_x, left_elbow_y, left_elbow_z, left_elbow_v,
    right_elbow_x, right_elbow_y, right_elbow_z, right_elbow_v,
    left_wrist_x, left_wrist_y, left_wrist_z, left_wrist_v,
    right_wrist_x, right_wrist_y, right_wrist_z, right_wrist_v,
    left_hip_x, left_hip_y, left_hip_z, left_hip_v,
    right_hip_x, right_hip_y, right_hip_z, right_hip_v,
    left_knee_x, left_knee_y, left_knee_z, left_knee_v,
    right_knee_x, right_knee_y, right_knee_z, right_knee_v,
    left_ankle_x, left_ankle_y, left_ankle_z, left_ankle_v,
    right_ankle_x, right_ankle_y, right_ankle_z, right_ankle_v,
    left_heel_x, left_heel_y, left_heel_z, left_heel_v,
    right_heel_x, right_heel_y, right_heel_z, right_heel_v,
    left_foot_index_x, left_foot_index_y, left_foot_index_z, left_foot_index_v,
    right_foot_index_x, right_foot_index_y, right_foot_index_z, right_foot_index_v
])

# %%
def predict_posture(features):
    features = features.reshape(1, -1)  # Reshape for the model input
    prediction = model.predict(features)  # Predict using the loaded model
    return prediction

# %%
if st.button('Predict'):
    result = predict_posture(input_data)
    st.write(f"The predicted posture is: {result}")
# Out:
# 2024-09-11 14:16:43.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:16:43.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:16:43.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-11 14:16:43.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
